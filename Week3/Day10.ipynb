# %% [markdown]
# ###### Linear Regression is used to explain for it Interpritability

# %%
# 1. The Realationship between Feature and Error Should be independent and Completly Correlated. If there is Dependency then Model is not Generalized
# 2. x1 and x2 should be indpendent of Each Other not dependent. y = 5x1 - x2 x1 were if x1 is increase then y but x2 is negative if it increase y get decreases.
# 3. In Second Assumption there should be Independent Variable.
# 
#
#
#
#
#
#

# %%
y = 4000*9-1*18000
y
# Out:
# 18000

# %%
# Pandas DataFrame

data = {
    "name":['a','b','c','d'],
    "age":[25,26,27,28],
    "city":['pune','mumbai','delhi','banglore'],
    "marks":[90,85,95,92]
}

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   name  age      city  marks
# 0    a   25      pune     90
# 1    b   26    mumbai     85
# 2    c   27     delhi     95
# 3    d   28  banglore     92

# %%
! pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      2.0.0
# altair                       5.1.2
# annotated-types              0.5.0
# appdirs                      1.4.4
# astor                        0.8.1
# asttokens                    2.2.1
# astunparse                   1.6.3
# asyncio                      3.4.3
# attrs                        23.1.0
# autograd                     1.6.2
# autograd-gamma               0.5.0
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleak                        0.21.1
# bleak-winrt                  1.2.0
# blinker                      1.6.3
# blis                         0.7.11
# bs4                          0.0.1
# cachetools                   5.3.1
# catalogue                    2.0.10
# certifi                      2023.7.22
# charset-normalizer           3.2.0
# clarabel                     0.7.1
# classification               0.1.0
# ...

# %%
df.head()
# Out:
#   name  age      city  marks
# 0    a   25      pune     90
# 1    b   26    mumbai     85
# 2    c   27     delhi     95
# 3    d   28  banglore     92

# %%
# Pandas DataFrame

data1 = {
    "name":['a','b','c','d'],
    "id":[25,26,27,28],
    
}

# %%
data1 = pd.DataFrame(data1)

# %%
df = pd.merge(df,data1,on='name',how='inner')
df.head()
# Out:
#   name  age      city  marks  id
# 0    a   25      pune     90  25
# 1    b   26    mumbai     85  26
# 2    c   27     delhi     95  27
# 3    d   28  banglore     92  28
